# %% [markdown]
# Python 操作 Excel 需要三方库的支持，
#
# 如果要兼容 Excel 2007 以前的版本，也就是xls格式的 Excel 文件，可以使用三方库xlrd和xlwt，前者用于读 Excel 文件，后者用于写 Excel 文件。以及配合使用的工具模块xlutils
#
# 使用较新版本的 Excel，即xlsx格式的 Excel 文件，可以使用openpyxl库，当然这个库不仅仅可以操作Excel，还可以操作其他基于 Office Open XML 的电子表格文件。
#
# > 由于python3.13不支持xlrd和xlwt，pandas可以进行处理，后续会介绍
